# %%
import random
a=0
oui=1
non=0
inconnu=-1
mine = 'M'

class cellule:
  def __init__(self, position, nbr_colonne):
    self.position = position
    self.ligne = position//nbr_colonne
    self.colonne = position%nbr_colonne
    self.inconnu = oui
    self.mine = non
    self.drapeau = non
    self.chiffre = 0
    self.nbr_colonne = nbr_colonne
  
  def show(self):
    if self.inconnu == oui :
      print('_' , end=" ")
    elif self.mine == oui :
      print(mine , end=" ")
    else :
      print(self.chiffre , end=" "),
    if self.colonne == self.nbr_colonne-1 :
      print('')
  
  def true(self):
    if self.mine == oui :
      print(mine , end=' ')
    else :
      print(self.chiffre , end=" ")
    if self.colonne == self.nbr_colonne-1 :
      print('') 
      
  def marquage(self):
    self.drapeau = 1-self.drapeau
    return(self.drapeau)
      
  
def position_proche(position, nbr_ligne, nbr_colonne):
  ligne = position//nbr_colonne
  colonne = position%nbr_colonne
  if ligne==0 :
    if colonne==0:
      return([position+1,position+nbr_colonne,position+nbr_colonne+1])
    elif colonne==nbr_colonne-1:
      return([position-1,position+nbr_colonne-1,position+nbr_colonne])
    else:
      return([position-1,position+1,position+nbr_colonne-1,position+nbr_colonne,position+nbr_colonne+1])
  elif ligne==nbr_ligne-1 :
    if colonne==0:
      return([position-nbr_colonne,position-nbr_colonne+1,position+1])
    elif colonne==nbr_colonne-1:
      return([position-nbr_colonne-1,position-nbr_colonne,position-1])
    else:
      return([position-nbr_colonne-1,position-nbr_colonne,position-nbr_colonne+1,position-1,position+1])
  else :
    if colonne==0:
      return([position-nbr_colonne,position-nbr_colonne+1,position+1,position+nbr_colonne,position+nbr_colonne+1])
    elif colonne==nbr_colonne-1:
      return([position-nbr_colonne-1,position-nbr_colonne,position-1,position+nbr_colonne-1,position+nbr_colonne])
    else:
      return([position-nbr_colonne-1,position-nbr_colonne,position-nbr_colonne+1,position-1,position+1,position+nbr_colonne-1,position+nbr_colonne,position+nbr_colonne+1])

class terrin:
  def __init__(self,nbr_ligne, nbr_colonne, nbr_mine):
    self.nbr_ligne = nbr_ligne
    self.nbr_colonne = nbr_colonne
    self.nbr_mine = nbr_mine
    graine = inconnu
    self.nbr_cellule = nbr_ligne*nbr_colonne
    self.positions_libre = [k for k in range(0,self.nbr_cellule)]
    self.positions_mines = []
    self.positions_drapeaux = []
    self.cellules = [ cellule(position, nbr_colonne) for position in range(self.nbr_cellule)]
  
  def fini(self):
    for position in self.positions_libre :
      if self.cellules[position].iconnu == non :
        return(non)
    return(oui)
  
  def perdu(self):
    
  
  def show(self):
    for cellule in self.cellules :
      cellule.show()
    print('')
    
  def true(self):
    for cellule in self.cellules :
      cellule.true()
    print('')

  def revelation(self,ligne,colonne):
    position = ligne*self.nbr_colonne + colonne
    if position in self.positions_mines :
      self.perdu()
    elif self.cellules[position].inconnu == oui :
      drapeaux_proches=0
      for proche in position_proche(position, self.nbr_ligne, self.nbr_colonne) :
        if proche in self.positions_drapeaux == non :
          drapeaux_proches+=1
      if drapeaux_proches == self.cellules[position].chiffre :
        for proche in position_proche(position, self.nbr_ligne, self.nbr_colonne) :
          if proche in self.positions_libre :
            if proche in positions_drapeau :
              self.perdu()
            if self.cellules[proche].inconnu == oui :
              self.revelation(proche//self.nbr_colonne,proche%self/nbr_colonne)
    else :
      self.cellules[position].inconnu = non
      if self.cellules[position].chiffre == 0:
        list_zero=[position]
        while len(list_zero)!=0:
          position = list_zero.pop()
          for proche in position_proche(position, self.nbr_ligne, self.nbr_colonne) :
            if self.cellules[proche].inconnu == oui :
              self.cellules[proche].inconnu=non
              if self.cellules[proche].chiffre==0 :
                list_zero.append(proche)
      self.show()
    
  def premiere_revelation(self,ligne,colonne):
    graine = ligne*self.nbr_colonne + colonne
    self.cellules[graine].inconnu = non
    self.cellules[graine].chiffre = 0
    positions_mines_possible = [position for position in range(self.nbr_cellule)]
    positions_mines_possible.remove(graine)
    for proche in position_proche(graine, self.nbr_ligne, self.nbr_colonne) :
      positions_mines_possible.remove(proche)
    for k in range(self.nbr_mine):
      position_mine=random.choice(positions_mines_possible)
      self.cellules[position_mine].mine=oui
      self.positions_mines.append(position_mine)
      self.positions_libre.remove(position_mine)
      positions_mines_possible.remove(position_mine)
      for proche in position_proche(position_mine, self.nbr_ligne, self.nbr_colonne) :
        self.cellules[proche].chiffre +=1
    self.revelation(ligne,colonne)
  
  def marquage(self,ligne,colonne):
    position=ligne*self.nbr_colonne+colonne
    if self.cellules[position].marquage :
      self.positions_drapeaux.append(position)
    else :
      self.positions_drapeaux.remove(position)





test = terrin(10,15,60)

test.show()

test.premiere_revelation(3,1)
    
test.show()

test.true()
# Out:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# 1 1 2 _ _ _ _ _ _ _ _ _ _ _ _
# 0 0 2 _ _ _ _ _ _ _ _ _ _ _ _
# 0 1 3 _ _ _ _ _ _ _ _ _ _ _ _
# 0 2 _ _ _ _ _ _ _ _ _ _ _ _ _
# 1 4 _ _ _ _ _ _ _ _ _ _ _ _ _
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# 1 1 2 _ _ _ _ _ _ _ _ _ _ _ _
# 0 0 2 _ _ _ _ _ _ _ _ _ _ _ _
# 0 1 3 _ _ _ _ _ _ _ _ _ _ _ _
# 0 2 _ _ _ _ _ _ _ _ _ _ _ _ _
# 1 4 _ _ _ _ _ _ _ _ _ _ _ _ _
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# 1 2 M M 2 1 2 M 2 2 3 M M 2 0
# ...

# %% [markdown]
# # Nouvelle section
